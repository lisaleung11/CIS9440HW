# %%
import pandas as pd
import numpy as np
import json
import requests
import re
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from io import StringIO
import os
from azure.storage.blob import BlobServiceClient
import pandas as pd
from io import BytesIO, StringIO
import sqlalchemy
from sqlalchemy import create_engine
import pyodbc

# %%
URL = "https://data.cdc.gov/api/views/hfr9-rurv/rows.csv?accessType=DOWNLOAD"

response = requests.get(URL, verify=False)
if response.status_code == 200:
    # Decode the content and read into DataFrame
    df_raw = pd.read_csv(BytesIO(response.content))
    # Print the first few rows to verify if the data has been read successfully
    print(df_raw.head())
    print(df_raw.columns)
    print(df_raw.shape)
    df_raw.info()
else:
    print("Failed to download the file.")
# Out:
# /Users/lisa/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.cdc.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                                      RowId  YearStart  YearEnd LocationAbbr  \
# 0    BRFSS~2022~2022~42~Q03~TMC01~AGE~RACE       2022     2022           PA
# 1    BRFSS~2022~2022~46~Q03~TMC01~AGE~RACE       2022     2022           SD
# 2    BRFSS~2022~2022~16~Q03~TMC01~AGE~RACE       2022     2022           ID
# 3    BRFSS~2022~2022~24~Q03~TMC01~AGE~RACE       2022     2022           MD
# 4  BRFSS~2022~2022~55~Q03~TMC01~AGE~GENDER       2022     2022           WI
#
#    LocationDesc Datasource          Class                     Topic  \
# 0  Pennsylvania      BRFSS  Mental Health  Frequent mental distress
# 1  South Dakota      BRFSS  Mental Health  Frequent mental distress
# 2         Idaho      BRFSS  Mental Health  Frequent mental distress
# 3      Maryland      BRFSS  Mental Health  Frequent mental distress
# 4     Wisconsin      BRFSS  Mental Health  Frequent mental distress
#
#                                             Question Data_Value_Unit  ...  \
# 0  Percentage of older adults who are experiencin...               %  ...
# 1  Percentage of older adults who are experiencin...               %  ...
# 2  Percentage of older adults who are experiencin...               %  ...
# 3  Percentage of older adults who are experiencin...               %  ...
# 4  Percentage of older adults who are experiencin...               %  ...
#
#             Stratification2                       Geolocation  ClassID  \
# 0  Native Am/Alaskan Native  POINT (-77.86070029 40.79373015)      C05
# 1    Asian/Pacific Islander  POINT (-100.3735306 44.35313005)      C05
# 2       Black, non-Hispanic    POINT (-114.36373 43.68263001)      C05
# 3       Black, non-Hispanic  POINT (-76.60926011 39.29058096)      C05
# 4                      Male  POINT (-89.81637074 44.39319117)      C05
#
#    TopicID QuestionID LocationID  StratificationCategoryID1  \
# 0    TMC01        Q03         42                        AGE
# 1    TMC01        Q03         46                        AGE
# 2    TMC01        Q03         16                        AGE
# 3    TMC01        Q03         24                        AGE
# 4    TMC01        Q03         55                        AGE
#
#    StratificationID1 StratificationCategoryID2 StratificationID2
# 0               5064                      RACE               NAA
# 1             65PLUS                      RACE               ASN
# 2             65PLUS                      RACE               BLK
# 3             65PLUS                      RACE               BLK
# 4             65PLUS                    GENDER              MALE
#
# [5 rows x 31 columns]
# Index(['RowId', 'YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc',
#        'Datasource', 'Class', 'Topic', 'Question', 'Data_Value_Unit',
#        'DataValueTypeID', 'Data_Value_Type', 'Data_Value', 'Data_Value_Alt',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'Geolocation', 'ClassID', 'TopicID', 'QuestionID',
#        'LocationID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2'],
#       dtype='object')
# (284142, 31)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284142 entries, 0 to 284141
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   RowId                       284142 non-null  object
#  1   YearStart                   284142 non-null  int64
#  2   YearEnd                     284142 non-null  int64
#  3   LocationAbbr                284142 non-null  object
#  4   LocationDesc                284142 non-null  object
#  5   Datasource                  284142 non-null  object
#  6   Class                       284142 non-null  object
#  7   Topic                       284142 non-null  object
#  8   Question                    284142 non-null  object
#  9   Data_Value_Unit             284142 non-null  object
#  10  DataValueTypeID             284142 non-null  object
#  11  Data_Value_Type             284142 non-null  object
#  12  Data_Value                  192808 non-null  float64
#  13  Data_Value_Alt              192808 non-null  float64
#  14  Data_Value_Footnote_Symbol  109976 non-null  object
#  15  Data_Value_Footnote         109976 non-null  object
#  16  Low_Confidence_Limit        192597 non-null  float64
#  17  High_Confidence_Limit       192597 non-null  float64
#  18  StratificationCategory1     284142 non-null  object
#  19  Stratification1             284142 non-null  object
#  20  StratificationCategory2     247269 non-null  object
#  21  Stratification2             247269 non-null  object
#  22  Geolocation                 253653 non-null  object
#  23  ClassID                     284142 non-null  object
#  24  TopicID                     284142 non-null  object
#  25  QuestionID                  284142 non-null  object
#  26  LocationID                  284142 non-null  int64
#  27  StratificationCategoryID1   284142 non-null  object
#  28  StratificationID1           284142 non-null  object
#  29  StratificationCategoryID2   284142 non-null  object
#  30  StratificationID2           284142 non-null  object
# dtypes: float64(4), int64(3), object(24)
# memory usage: 67.2+ MB

# %%
df_cleaned = df_raw.copy()
df_cleaned = df_raw.drop(columns=  ['LocationAbbr','Data_Value_Footnote_Symbol','Data_Value_Footnote','Datasource','Data_Value_Unit','Data_Value_Alt','StratificationCategory1','StratificationCategoryID1'])
df_cleaned = df_cleaned.dropna(subset=['Data_Value'])
df_cleaned.info()


df_cleaned['Longitude'] = None
df_cleaned['Latitude'] = None

for index, row in df_cleaned.iterrows():
    geolocation = row['Geolocation']
    if isinstance(geolocation, float):
        continue  # Skip float values
    if geolocation:
        match = re.match(r'POINT \(([-0-9.]+) ([-0-9.]+)\)', geolocation)
        if match:
            longitude = float(match.group(1))
            latitude = float(match.group(2))
            df_cleaned.at[index, 'Longitude'] = longitude
            df_cleaned.at[index, 'Latitude'] = latitude

alzheimer_df = df_cleaned.copy()

alzheimer_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 192808 entries, 3 to 284137
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   RowId                      192808 non-null  object
#  1   YearStart                  192808 non-null  int64
#  2   YearEnd                    192808 non-null  int64
#  3   LocationDesc               192808 non-null  object
#  4   Class                      192808 non-null  object
#  5   Topic                      192808 non-null  object
#  6   Question                   192808 non-null  object
#  7   DataValueTypeID            192808 non-null  object
#  8   Data_Value_Type            192808 non-null  object
#  9   Data_Value                 192808 non-null  float64
#  10  Low_Confidence_Limit       192597 non-null  float64
#  11  High_Confidence_Limit      192597 non-null  float64
#  12  Stratification1            192808 non-null  object
#  13  StratificationCategory2    156041 non-null  object
#  14  Stratification2            156041 non-null  object
#  15  Geolocation                162742 non-null  object
#  16  ClassID                    192808 non-null  object
#  17  TopicID                    192808 non-null  object
#  18  QuestionID                 192808 non-null  object
#  19  LocationID                 192808 non-null  int64
#  20  StratificationID1          192808 non-null  object
#  21  StratificationCategoryID2  192808 non-null  object
#  22  StratificationID2          192808 non-null  object
# dtypes: float64(3), int64(3), object(17)
# memory usage: 35.3+ MB
#                                      RowId  YearStart  YearEnd  LocationDesc  \
# 3    BRFSS~2022~2022~24~Q03~TMC01~AGE~RACE       2022     2022      Maryland
# 4  BRFSS~2022~2022~55~Q03~TMC01~AGE~GENDER       2022     2022     Wisconsin
# 6    BRFSS~2022~2022~40~Q03~TMC01~AGE~RACE       2022     2022      Oklahoma
# 7    BRFSS~2022~2022~42~Q03~TMC01~AGE~RACE       2022     2022  Pennsylvania
# 8  BRFSS~2022~2022~42~Q46~TOC10~AGE~GENDER       2022     2022  Pennsylvania
#
#             Class                                              Topic  \
# 3   Mental Health                           Frequent mental distress
# 4   Mental Health                           Frequent mental distress
# 6   Mental Health                           Frequent mental distress
# 7   Mental Health                           Frequent mental distress
# 8  Overall Health  Disability status, including sensory or mobili...
#
#                                             Question DataValueTypeID  \
# 3  Percentage of older adults who are experiencin...           PRCTG
# 4  Percentage of older adults who are experiencin...           PRCTG
# 6  Percentage of older adults who are experiencin...           PRCTG
# 7  Percentage of older adults who are experiencin...           PRCTG
# 8  Percentage of older adults who report having a...           PRCTG
#
#   Data_Value_Type  Data_Value  ...                       Geolocation  ClassID  \
# 3      Percentage         9.0  ...  POINT (-76.60926011 39.29058096)      C05
# 4      Percentage         5.6  ...  POINT (-89.81637074 44.39319117)      C05
# 6      Percentage        21.5  ...  POINT (-97.52107021 35.47203136)      C05
# 7      Percentage        10.0  ...  POINT (-77.86070029 40.79373015)      C05
# 8      Percentage        39.9  ...  POINT (-77.86070029 40.79373015)      C01
#
#   TopicID QuestionID LocationID StratificationID1 StratificationCategoryID2  \
# 3   TMC01        Q03         24            65PLUS                      RACE
# 4   TMC01        Q03         55            65PLUS                    GENDER
# 6   TMC01        Q03         40       AGE_OVERALL                      RACE
# 7   TMC01        Q03         42       AGE_OVERALL                      RACE
# 8   TOC10        Q46         42       AGE_OVERALL                    GENDER
#
#   StratificationID2  Longitude   Latitude
# 3               BLK  -76.60926  39.290581
# 4              MALE -89.816371  44.393191
# 6               NAA  -97.52107  35.472031
# 7               WHT   -77.8607   40.79373
# 8            FEMALE   -77.8607   40.79373
#
# [5 rows x 25 columns]

# %%
#connecting azure
config_file_path = "config.json"

with open(config_file_path, 'r') as config_file:
  config = json.load(config_file)

CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
CONTAINER_AZURE = 'alzheimer'
blob_name = "alzheimer.csv"
# Convert DataFrame to CSV
output = StringIO()
df_raw.to_csv(output, index=False)
data = output.getvalue()
output.close()

csv_string = alzheimer_df.to_csv(index=False)

# Initialize BlobServiceClient
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

# Get the container client
container_client = blob_service_client.get_container_client(CONTAINER_AZURE)

# Upload the CSV string to Azure Blob Storage
# add raw data code
blob_client = container_client.get_blob_client(blob="alzheimer_data.csv")

blob_client.upload_blob(csv_string)

print(f"Uploaded {blob_name} to Azure Blob Storage in container {CONTAINER_AZURE}.")
# Out:
# Uploaded alzheimer.csv to Azure Blob Storage in container alzheimer.

# %%
topic_df = df_cleaned[['TopicID', 'Topic']]

# Dropping duplicates to get unique QuestionID pairs with questions
unique_topic_df = topic_df.drop_duplicates()

# Mapping dictionary
question_mapping = dict(zip(unique_topic_df['TopicID'], unique_topic_df['Topic']))

# Applying the mapping to create a new column with descriptions
df_cleaned['Topic'] = df_cleaned['TopicID'].map(question_mapping)
unique_topic_df = unique_topic_df.rename(columns={'TopicID': 'topic_id', 'Topic': 'topic_desc'})
unique_topic_df
# Out:
#       topic_id                                         topic_desc
# 3        TMC01                           Frequent mental distress
# 8        TOC10  Disability status, including sensory or mobili...
# 10       TOC05                      Oral health:  tooth retention
# 16       TSC09                      Ever had pneumococcal vaccine
# 20       TSC10  Up-to-date with recommended vaccines and scree...
# 26       TSC11  Up-to-date with recommended vaccines and scree...
# 33       TSC01                      Mammogram within past 2 years
# 40       TSC03                       Pap test within past 3 years
# 47       TNC04                                            Obesity
# 52       TSC02                        Colorectal cancer screening
# 55       TNC03  No leisure-time physical activity within past ...
# 63       TAC01                                    Current smoking
# 69       TSC08                 Influenza vaccine within past year
# 78       TSC04             Diabetes screening within past 3 years
# 80       TAC03                 Binge drinking within past 30 days
# 86       TMC03                   Lifetime diagnosis of depression
# 91       TCC02  Functional difficulties associated with subjec...
# 92       TCC04  Talked with health care professional about sub...
# 96       TOC07            Self-rated health (fair to poor health)
# 100      TOC08       Self-rated health (good to excellent health)
# 101      TOC09                     Prevalence of sufficient sleep
# 107      TOC03          Recent activity limitations in past month
# 108      TGC01  Provide care for a friend or family member in ...
# 109      TGC03          Duration of caregiving among older adults
# 112      TGC04         Intensity of caregiving among older adults
# 114      TGC02  Expect to provide care for someone in the next...
# 116      TOC11                       Arthritis among older adults
# 121      TOC13  Fair or poor health among older adults with ar...
# 178      TGC05  Provide care for someone with cognitive impair...
# 183      TCC01  Subjective cognitive decline or memory loss am...
# 192      TCC03  Need assistance with day-to-day activities bec...
# 203      TNC01                      Eating 2 or more fruits daily
# 208      TNC02                  Eating 3 or more vegetables daily
# 222      TOC04          Taking medication for high blood pressure
# 227      TOC01    Physically unhealthy days (mean number of days)
# 52042    TSC07                           High blood pressure ever
# 52050    TSC06                Cholesterol checked in past 5 years
# 62648    TOC12  Severe joint pain among older adults with arth...
# 73116    TOC06                  Fall with injury within last year

# %%
class_df = df_cleaned[['ClassID', 'Class']]

# Dropping duplicates to get unique QuestionID pairs with questions
unique_class_df = class_df.drop_duplicates()

# Mapping dictionary
class_mapping = dict(zip(unique_class_df['ClassID'], unique_class_df['Class']))

# Applying the mapping to create a new column with descriptions
df_cleaned['Class'] = df_cleaned['ClassID'].map(class_mapping)
unique_class_df = unique_class_df.rename(columns={'ClassID': 'class_id', 'Class': 'class_desc'})
unique_class_df
# Out:
#     class_id                           class_desc
# 3        C05                        Mental Health
# 8        C01                       Overall Health
# 16       C03              Screenings and Vaccines
# 47       C02  Nutrition/Physical Activity/Obesity
# 63       C04              Smoking and Alcohol Use
# 91       C06                    Cognitive Decline
# 108      C07                           Caregiving

# %%
question_df = df_cleaned[['QuestionID', 'Question']]

# Dropping duplicates to get unique QuestionID pairs with questions
unique_questions_df = question_df.drop_duplicates()

# Mapping dictionary
question_mapping = dict(zip(unique_questions_df['QuestionID'], unique_questions_df['Question']))

# Applying the mapping to create a new column with descriptions
df_cleaned['question_desc'] = df_cleaned['QuestionID'].map(question_mapping)
unique_questions_df = unique_questions_df.rename(columns={'QuestionID': 'question_id', 'Question': 'question_desc'})
unique_questions_df
# Out:
#       question_id                                      question_desc
# 3             Q03  Percentage of older adults who are experiencin...
# 8             Q46  Percentage of older adults who report having a...
# 10            Q07  Percentage of older adults who report having l...
# 16            Q09  Percentage of at risk adults (have diabetes, a...
# 20            Q10  Percentage of older adult men who are up to da...
# 26            Q11  Percentage of older adult women who are up to ...
# 33            Q12  Percentage of older adult women who have recei...
# 40            Q20  Percentage of older adult women with an intact...
# 47            Q13  Percentage of older adults who are currently o...
# 52            Q15  Percentage of older adults who had either a ho...
# 55            Q16  Percentage of older adults who have not had an...
# 63            Q17  Percentage of older adults who have smoked at ...
# 69            Q18  Percentage of older adults who reported influe...
# 78            Q19  Percentage of older adults without diabetes wh...
# 80            Q21  Percentage of older adults who reported binge ...
# 86            Q27  Percentage of older adults with a lifetime dia...
# 91            Q31  Percentage of older adults who reported subjec...
# 92            Q42  Percentage of older adults with subjective cog...
# 96            Q32  Percentage of older adults who self-reported t...
# 100           Q33  Percentage of older adults who self-reported t...
# 101           Q34  Percentage of older adults getting sufficient ...
# 107           Q35  Mean number of days with activity limitations ...
# 108           Q36  Percentage of older adults who provided care f...
# 109           Q38  Percentage of older adults who provided care t...
# 112           Q39  Average of 20 or more hours of care per week p...
# 114           Q37  Percentage of older adults currently not provi...
# 116           Q43  Percentage of older adults ever told they have...
# 121           Q45  Fair or poor health among older adults with do...
# 178           Q40  Percentage of older adults who provided care f...
# 183           Q30  Percentage of older adults who reported subjec...
# 192           Q41  Percentage of older adults who reported that a...
# 203           Q01  Percentage of older adults who are eating 2 or...
# 208           Q02  Percentage of older adults who are eating 3 or...
# 222           Q04  Percentage of older adults who have been told ...
# 227           Q08  Physically unhealthy days (mean number of days...
# 52042         Q22  Percentage of older adults who have ever been ...
# 52050         Q14  Percentage of older adults who had a cholester...
# 62648         Q44  Severe joint pain due to arthritis among older...
# 73116         Q05  Percentage of older adults who have fallen and...

# %%
location_lookup_df = pd.read_csv('/Users/lisa/CIS9440HW/docs/filtered_location.csv')
location_lookup_df = location_lookup_df.fillna(0)
new_order = ['location_id', 'location_desc','latitude','longitude']
location_lookup_df = location_lookup_df[new_order]
location_lookup_df.head()
# Out:
#    location_id         location_desc   latitude  longitude
# 0         9003                 South   0.000000   0.000000
# 1         9001             Northeast   0.000000   0.000000
# 2            9           Connecticut  41.562661 -72.649841
# 3           11  District of Columbia  38.907192 -77.036871
# 4           10              Delaware  39.008831 -75.577741

# %%
# Creating Year Dimension

# Mapping dictionary
year_mapping = {
    2015: 2015,
    2016: 2016,
    2017: 2017,
    2018: 2018,
    2019: 2019,
    2020: 2020,
    2021: 2021,
    2022: 2022
}

unique_syear_ids = df_cleaned['YearStart'].unique()
# Converting the array of unique values into a DataFrame
unique_syear_df = pd.DataFrame(unique_syear_ids, columns=['year_id'])

# Applying the mapping to create a new column with descriptions
unique_syear_df['year'] = unique_syear_df['year_id'].map(year_mapping)
unique_syear_df = unique_syear_df[unique_syear_df['year_id'] != '<NA>']
unique_syear_df
# Out:
#    year_id  year
# 0     2022  2022
# 1     2021  2021
# 2     2019  2019
# 3     2020  2020
# 4     2018  2018
# 5     2015  2015
# 6     2017  2017
# 7     2016  2016

# %%
stratification_category2_df = df_cleaned[['StratificationCategoryID2', 'StratificationCategory2']]

# Dropping duplicates to get unique QuestionID pairs with questions
unique_stratification_category2_df = stratification_category2_df.drop_duplicates()

# Mapping dictionary
stratification_category2_mapping = dict(zip(unique_stratification_category2_df['StratificationCategoryID2'], unique_stratification_category2_df['StratificationCategory2']))

# Applying the mapping to create a new column with descriptions
df_cleaned['stratification_category2'] = df_cleaned['StratificationCategoryID2'].map(stratification_category2_mapping)
unique_stratification_category2_df = unique_stratification_category2_df.rename(columns={'StratificationCategoryID2': 'stratification_categoryid2', 'StratificationCategory2': 'stratification_category2'})
unique_stratification_category2_df
# Out:
#    stratification_categoryid2 stratification_category2
# 3                        RACE           Race/Ethnicity
# 4                      GENDER                   Gender
# 52                    OVERALL                      NaN

# %%
stratification2_df = df_cleaned[['StratificationID2', 'Stratification2']]

# Dropping duplicates to get unique QuestionID pairs with questions
unique_stratification2_df = stratification2_df.drop_duplicates()

# Mapping dictionary
stratification2_mapping = dict(zip(unique_stratification2_df['StratificationID2'], unique_stratification2_df['Stratification2']))

# Applying the mapping to create a new column with descriptions
df_cleaned['stratification2'] = df_cleaned['StratificationID2'].map(stratification2_mapping)
unique_stratification2_df = unique_stratification2_df.rename(columns={'StratificationID2': 'stratification2_id', 'Stratification2': 'stratification2'})
unique_stratification2_df
# Out:
#    stratification2_id           stratification2
# 3                 BLK       Black, non-Hispanic
# 4                MALE                      Male
# 6                 NAA  Native Am/Alaskan Native
# 7                 WHT       White, non-Hispanic
# 8              FEMALE                    Female
# 10                ASN    Asian/Pacific Islander
# 12                HIS                  Hispanic
# 52            OVERALL                       NaN

# %%
stratification1_df = df_cleaned[['StratificationID1', 'Stratification1']]

# Dropping duplicates to get unique QuestionID pairs with questions
unique_stratification1_df = stratification1_df.drop_duplicates()

# Mapping dictionary
stratification1_mapping = dict(zip(unique_stratification1_df['StratificationID1'], unique_stratification1_df['Stratification1']))

# Applying the mapping to create a new column with descriptions
df_cleaned['stratification1'] = df_cleaned['StratificationID1'].map(stratification1_mapping)
unique_stratification1_df = unique_stratification1_df.rename(columns={'StratificationID1': 'stratification1_id', 'Stratification1': 'stratification1'})
unique_stratification1_df
# Out:
#    stratification1_id    stratification1
# 3              65PLUS  65 years or older
# 6         AGE_OVERALL            Overall
# 26               5064        50-64 years

# %%
percent_df = df_cleaned[df_cleaned['Data_Value'] != mean_value]
 
percent_df.reset_index(drop = True,inplace=True)
percent_df['stratification_id'] = percent_df.index
 
new_column_names = {
    'RowId': 'fact_id',
	'Data_Value':'data_value',
	'Low_Confidence_Limit': 'low_confidence_limit',
	'High_Confidence_Limit': 'high_confidence_limit',
	'TopicID': 'topic_id',
	'ClassID': 'class_id', 
	'QuestionID': 'question_id',
    'LocationID': 'location_id',
    'YearStart': 'year_start',
    'YearEnd': 'year_end',
    'StratificationID1': 'stratification1_id',
    'StratificationID2': 'stratification2_id',
    'StratificationCategoryID2': 'stratification_categoryid2'
}
 
percent_df = percent_df.rename(columns=new_column_names)
new_order = ['fact_id', 'data_value', 'low_confidence_limit', 'high_confidence_limit', 'location_id', 'topic_id', 'class_id', 'year_start', 'year_end','question_id','stratification1_id','stratification2_id','stratification_categoryid2']
percent_df = percent_df[new_order]
percent_df.head(20)
# Out:
#                                     fact_id  data_value  low_confidence_limit  \
# 0     BRFSS~2022~2022~24~Q03~TMC01~AGE~RACE         9.0                   6.5
# 1   BRFSS~2022~2022~55~Q03~TMC01~AGE~GENDER         5.6                   4.4
# 2     BRFSS~2022~2022~40~Q03~TMC01~AGE~RACE        21.5                  15.4
# 3     BRFSS~2022~2022~42~Q03~TMC01~AGE~RACE        10.0                   8.3
# 4   BRFSS~2022~2022~42~Q46~TOC10~AGE~GENDER        39.9                  35.6
# 5     BRFSS~2022~2022~05~Q46~TOC10~AGE~RACE        61.9                  45.9
# 6     BRFSS~2022~2022~24~Q07~TOC05~AGE~RACE        71.5                  50.0
# 7     BRFSS~2022~2022~36~Q07~TOC05~AGE~RACE        73.9                  60.4
# 8     BRFSS~2022~2022~04~Q07~TOC05~AGE~RACE        64.3                  56.4
# 9     BRFSS~2022~2022~46~Q07~TOC05~AGE~RACE        52.6                  28.9
# 10    BRFSS~2022~2022~59~Q03~TMC01~AGE~RACE        10.8                   9.5
# 11  BRFSS~2022~2022~9001~Q46~TOC10~AGE~RACE        42.4                  33.4
# 12    BRFSS~2022~2022~20~Q09~TSC09~AGE~RACE        50.8                  37.8
# 13  BRFSS~2022~2022~53~Q09~TSC09~AGE~GENDER        61.2                  59.3
# 14    BRFSS~2022~2022~53~Q09~TSC09~AGE~RACE        56.5                  44.8
# 15    BRFSS~2022~2022~50~Q09~TSC09~AGE~RACE        65.0                  62.5
# 16    BRFSS~2022~2022~15~Q10~TSC10~AGE~RACE        45.1                  38.5
# 17    BRFSS~2022~2022~11~Q10~TSC10~AGE~RACE        47.5                  37.0
# 18    BRFSS~2022~2022~08~Q10~TSC10~AGE~RACE        41.8                  28.7
# 19    BRFSS~2022~2022~15~Q10~TSC10~AGE~RACE        43.8                  38.9
#
#     high_confidence_limit  location_id topic_id class_id  year_start  \
# 0                    12.3           24    TMC01      C05        2022
# 1                     7.2           55    TMC01      C05        2022
# 2                    29.2           40    TMC01      C05        2022
# 3                    12.1           42    TMC01      C05        2022
# 4                    44.4           42    TOC10      C01        2022
# 5                    75.6            5    TOC10      C01        2022
# 6                    86.3           24    TOC05      C01        2022
# 7                    84.0           36    TOC05      C01        2022
# 8                    71.6            4    TOC05      C01        2022
# 9                    75.1           46    TOC05      C01        2022
# 10                   12.2           59    TMC01      C05        2022
# 11                   51.9         9001    TOC10      C01        2022
# 12                   63.6           20    TSC09      C03        2022
# 13                   63.1           53    TSC09      C03        2022
# 14                   67.6           53    TSC09      C03        2022
# 15                   67.5           50    TSC09      C03        2022
# 16                   51.9           15    TSC10      C03        2022
# 17                   58.2           11    TSC10      C03        2022
# 18                   56.1            8    TSC10      C03        2022
# 19                   48.9           15    TSC10      C03        2022
#
#     year_end question_id stratification1_id stratification2_id  \
# 0       2022         Q03             65PLUS                BLK
# 1       2022         Q03             65PLUS               MALE
# 2       2022         Q03        AGE_OVERALL                NAA
# 3       2022         Q03        AGE_OVERALL                WHT
# 4       2022         Q46        AGE_OVERALL             FEMALE
# 5       2022         Q46        AGE_OVERALL                NAA
# 6       2022         Q07             65PLUS                ASN
# 7       2022         Q07             65PLUS                ASN
# 8       2022         Q07             65PLUS                HIS
# 9       2022         Q07             65PLUS                NAA
# 10      2022         Q03             65PLUS                BLK
# 11      2022         Q46             65PLUS                ASN
# 12      2022         Q09        AGE_OVERALL                HIS
# 13      2022         Q09        AGE_OVERALL               MALE
# 14      2022         Q09        AGE_OVERALL                NAA
# 15      2022         Q09        AGE_OVERALL                WHT
# 16      2022         Q10             65PLUS                ASN
# 17      2022         Q10             65PLUS                BLK
# 18      2022         Q10             65PLUS                HIS
# 19      2022         Q10        AGE_OVERALL                ASN
#
#    stratification_categoryid2
# 0                        RACE
# 1                      GENDER
# 2                        RACE
# 3                        RACE
# 4                      GENDER
# 5                        RACE
# 6                        RACE
# 7                        RACE
# 8                        RACE
# 9                        RACE
# 10                       RACE
# 11                       RACE
# 12                       RACE
# 13                     GENDER
# 14                       RACE
# 15                       RACE
# 16                       RACE
# 17                       RACE
# 18                       RACE
# 19                       RACE

# %%
mean_df = df_cleaned[df_cleaned['Data_Value_Type'] != 'Percentage']

new_column_names = {
    'RowId': 'fact_id',
	'Data_Value':'data_value',
	'Low_Confidence_Limit': 'low_confidence_limit',
	'High_Confidence_Limit': 'high_confidence_limit',
	'TopicID': 'topic_id',
	'ClassID': 'class_id', 
	'QuestionID': 'question_id',
    'LocationID': 'location_id',
    'YearStart': 'year_start',
    'YearEnd': 'year_end',
    'StratificationID1': 'stratification1_id',
    'StratificationID2': 'stratification2_id',
    'StratificationCategoryID2': 'stratification_categoryid2'
}

mean_df = mean_df.rename(columns=new_column_names)
new_order = ['fact_id', 'data_value', 'low_confidence_limit', 'high_confidence_limit', 'location_id', 'topic_id', 'class_id', 'year_start', 'year_end','question_id','stratification1_id','stratification2_id','stratification_categoryid2']
mean_df = mean_df[new_order]
mean_df.head(10)
mean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15173 entries, 107 to 284121
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fact_id                     15173 non-null  object
#  1   data_value                  15173 non-null  float64
#  2   low_confidence_limit        15173 non-null  float64
#  3   high_confidence_limit       15173 non-null  float64
#  4   location_id                 15173 non-null  int64
#  5   topic_id                    15173 non-null  object
#  6   class_id                    15173 non-null  object
#  7   year_start                  15173 non-null  int64
#  8   year_end                    15173 non-null  int64
#  9   question_id                 15173 non-null  object
#  10  stratification1_id          15173 non-null  object
#  11  stratification2_id          15173 non-null  object
#  12  stratification_categoryid2  15173 non-null  object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1.6+ MB

# %%
# Database connection URL
# Replace the placeholders with your actual database credentials
pwd = 'Cis9440dw124!'
database_url = f'postgresql://laishan:{pwd}@cis9440baruchdw.postgres.database.azure.com/postgres'

# Create a SQLAlchemy engine
engine = create_engine(database_url)

# %%
unique_topic_df.to_sql('dim_topic', con=engine, schema='alzheimer', if_exists='append', index=False)

# %%
unique_topic_df.to_csv("topic.csv",index=False)

# %%
unique_class_df.to_sql('dim_class', con=engine, schema='alzheimer', if_exists='append', index=False)

# %%
unique_class_df.to_csv("class.csv",index=False)

# %%
unique_questions_df.to_sql('dim_question', con=engine, schema='alzheimer', if_exists='append', index=False)

# %%
unique_questions_df.to_csv("questions.csv",index=False)

# %%
location_lookup_df.to_sql('dim_location', con=engine, schema='alzheimer', if_exists='append', index=False)
# Out:
# 59

# %%
location_lookup_df.to_csv("location.csv",index=False)

# %%
unique_stratification_category2_df.to_sql('dim_stratification_category', con=engine, schema='alzheimer', if_exists='append', index=False)
# Out:
# 3

# %%
unique_stratification_category2_df.to_csv("stratification_category2.csv",index=False)

# %%
unique_stratification1_df.to_sql('dim_stratification1', con=engine, schema='alzheimer', if_exists='append', index=False)
# Out:
# 3

# %%
unique_stratification1_df.to_csv("stratification1.csv",index=False)

# %%
unique_stratification2_df.to_sql('dim_stratification2', con=engine, schema='alzheimer', if_exists='append', index=False)
# Out:
# 8

# %%
unique_stratification2_df.to_csv("stratification2.csv",index=False)

# %%
unique_syear_df.to_sql('dim_year', con=engine, schema='alzheimer', if_exists='append', index=False)
# Out:
# 8

# %%
unique_syear_df.to_csv("syear.csv",index=False)

# %%
percent_df.to_sql('facts_data_value_percentage', con=engine, schema='alzheimer', if_exists='append', index=False)
# Out:
# 808

# %%
percent_df.to_csv("percent.csv",index=False)

# %%
mean_df.to_sql('facts_data_value_mean', con=engine, schema='alzheimer', if_exists='append', index=False)

# %%
mean_df.to_csv("mean.csv",index=False)
